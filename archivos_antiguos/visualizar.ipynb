# %%
import pandas as pd
df_hogares = pd.read_csv(r'hogares_vulnerables_climaticos.csv')
df_hogares.head()
# Out:
#     folioviv  camb_clim  climate_vulnerability_intensity
# 0  100001901          0                                0
# 1  100001902          0                                0
# 2  100001904          0                                0
# 3  100001905          0                                0
# 4  100002501          0                                0

# %%
df_hogares.camb_clim.value_counts()
# Out:
# camb_clim
# 0    75889
# 1    15525
# Name: count, dtype: int64

# %%
df_hogares.climate_vulnerability_intensity.value_counts()
# Out:
# climate_vulnerability_intensity
# 0     75889
# 8     14711
# 9       778
# 10       33
# 11        2
# 12        1
# Name: count, dtype: int64

# %%
# Vamos a realizar la concatenación de los datasets para el desarrollo del trabajo, por lo que se realiza la carga de cada uno de ellos
df_concentradohogar = pd.read_csv('selected_concentradohogar.csv')
df_hogares = pd.read_csv('selected_hogares_cleaned.csv')
df_viviendas = pd.read_csv('selected_viviendas.csv')

# %%
df_final = pd.concat([df_concentradohogar, df_hogares, df_viviendas], ignore_index=True)
df_final.columns
# Out:
# Index(['folioviv', 'foliohog', 'ing_cor', 'gasto_mon', 'ubica_geo', 'tam_loc',
#        'acc_alim2', 'acc_alim7', 'acc_alim9', 'celular', 'tsalud1_h',
#        'tsalud1_m', 'camb_clim', 'f_sequia', 'f_inunda', 'f_helada',
#        'f_incendio', 'f_huracan', 'f_desliza', 'f_otro', 'af_viv', 'af_empleo',
#        'af_negocio', 'af_cultivo', 'af_trabajo', 'af_salud', 'af_otro',
#        'tot_resid', 'mat_pared', 'mat_techos', 'ab_agua', 'agua_noe',
#        'dotac_agua', 'sanit_agua', 'drenaje'],
#       dtype='object')

# %%
# Pensar en qué es lo que hay que hacer en los siguientes pasos, qué significa cada uno de estos campos, etc.
